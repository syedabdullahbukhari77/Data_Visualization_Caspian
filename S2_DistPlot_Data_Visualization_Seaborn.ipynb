# %% [markdown]
# ##**Import Libraries**

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##**Loadind Datasets**

# %%
df = pd.read_csv('/content/drive/MyDrive/Data-Sciecne(Funcdamentals)/S_Seaborn_Data_Science/planets.csv')
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ##**Dist Plot**

# %%
sns.distplot(df['year'] , bins = 20 , color = 'yellow')
# Out:
# <ipython-input-4-53f43efb6df9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['year'] , bins = 20 , color = 'yellow')
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.distplot(df['year'] , bins = 20 , color = 'pink' , kde = False)
# Out:
# <ipython-input-6-869440564d79>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['year'] , bins = 20 , color = 'pink' , kde = False)
# <Axes: xlabel='year'>

# %%
sns.distplot(df['distance'] , bins = 20 , color = 'green')
# Out:
# <ipython-input-5-3a81ffa18ac7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['distance'] , bins = 20 , color = 'green')
# <Axes: xlabel='distance', ylabel='Density'>

# %%
bins = 20

# %%
sns.distplot(df['distance'] , hist_kws = {'color' : 'black' , 'edgecolor' : 'sky blue' , 'linewidth' : 12})
plt.figure(figsize = (30,20))
# Out:
# <ipython-input-17-013b49dd9a51>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['distance'] , hist_kws = {'color' : 'black' , 'edgecolor' : 'sky blue' , 'linewidth' : 12})
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-013b49dd9a51> in <cell line: 1>()
# ----> 1 sns.distplot(df['distance'] , hist_kws = {'color' : 'black' , 'edgecolor' : 'sky blue' , 'linewidth' : 12})
#       2 plt.figure(figsize = (30,20))
#
# ...

# %%
sns.distplot(df['distance'] , bins = bins , rug = True , hist_kws = {'color' : 'yellow' , 'edgecolor' : 'blue' , 'linewidth' : 3 , 'alpha' : 0.5} , kde={'color' : 'red' , 'linewidth' : 5 })
plt.xticks(bins)
# Out:
# <ipython-input-20-06c9282f9e86>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['distance'] , bins = bins , rug = True , hist_kws = {'color' : 'yellow' , 'edgecolor' : 'blue' , 'linewidth' : 3 , 'alpha' : 0.5} , kde={'color' : 'red' , 'linewidth' : 5 })
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-06c9282f9e86> in <cell line: 2>()
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# ... your existing code ...

sns.distplot(df['distance'], bins=bins, rug=True, hist_kws={'color': 'yellow', 'edgecolor': 'blue', 'linewidth': 3, 'alpha': 0.5}, kde={'color': 'red', 'linewidth': 5})

# Generate x-tick locations based on the data range and desired number of bins
x_ticks = np.linspace(df['distance'].min(), df['distance'].max(), bins)
plt.xticks(x_ticks)

plt.show()
# Out:
# <ipython-input-21-c918d673180f>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['distance'], bins=bins, rug=True, hist_kws={'color': 'yellow', 'edgecolor': 'blue', 'linewidth': 3, 'alpha': 0.5}, kde={'color': 'red', 'linewidth': 5})
